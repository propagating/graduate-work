# %% [markdown]
# # Boilerplate

# %%
# !pip install --upgrade https://github.com/arviz-devs/arviz/archive/v0.11.1.zip
# !pip install --upgrade https://github.com/pymc-devs/pymc3/archive/v3.10.0.zip

import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import numpy as np
import pymc3 as pm
import arviz as az
# Out:
# Collecting https://github.com/arviz-devs/arviz/archive/v0.11.1.zip
#   Using cached https://github.com/arviz-devs/arviz/archive/v0.11.1.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (20.9)
# Requirement already satisfied, skipping upgrade: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (1.19.5)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (3.2.2)
# Requirement already satisfied, skipping upgrade: typing-extensions<4,>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: setuptools>=38.4 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (54.2.0)
# Requirement already satisfied, skipping upgrade: xarray>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (0.17.0)
# Requirement already satisfied, skipping upgrade: netcdf4 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (1.5.6)
# Requirement already satisfied, skipping upgrade: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (1.4.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from arviz==0.11.1) (1.1.5)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->arviz==0.11.1) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz==0.11.1) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz==0.11.1) (1.3.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz==0.11.1) (2.8.1)
# Requirement already satisfied, skipping upgrade: cftime in /usr/local/lib/python3.7/dist-packages (from netcdf4->arviz==0.11.1) (1.4.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->arviz==0.11.1) (2018.9)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from cycler>=0.10->matplotlib>=3.0->arviz==0.11.1) (1.15.0)
# Building wheels for collected packages: arviz
#   Building wheel for arviz (PEP 517) ... done
#   Created wheel for arviz: filename=arviz-0.11.1-cp37-none-any.whl size=1549418 sha256=38e971ac8fe20c360e6846a5b2c5e033b74d918c465d46e20257a864582f7b64
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m30pg5f3/wheels/58/bf/14/51f5f1138a3d2e58a512e4013080bf35db8748f2651ad38e81
# Successfully built arviz
# Installing collected packages: arviz
#   Found existing installation: arviz 0.11.1
#     Uninstalling arviz-0.11.1:
#       Successfully uninstalled arviz-0.11.1
# Successfully installed arviz-0.11.1
# Collecting https://github.com/pymc-devs/pymc3/archive/v3.10.0.zip
#   Using cached https://github.com/pymc-devs/pymc3/archive/v3.10.0.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied, skipping upgrade: fastprogress>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (1.0.0)
# Requirement already satisfied, skipping upgrade: arviz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (0.11.1)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: theano-pymc==1.0.11 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (1.0.11)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: dill in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (0.3.3)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (1.4.1)
# Requirement already satisfied, skipping upgrade: patsy>=0.5.1 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (0.5.1)
# Requirement already satisfied, skipping upgrade: pandas>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from pymc3==3.10.0) (1.1.5)
# Requirement already satisfied, skipping upgrade: xarray>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from arviz>=0.9.0->pymc3==3.10.0) (0.17.0)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.7/dist-packages (from arviz>=0.9.0->pymc3==3.10.0) (20.9)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0 in /usr/local/lib/python3.7/dist-packages (from arviz>=0.9.0->pymc3==3.10.0) (3.2.2)
# Requirement already satisfied, skipping upgrade: setuptools>=38.4 in /usr/local/lib/python3.7/dist-packages (from arviz>=0.9.0->pymc3==3.10.0) (54.2.0)
# Requirement already satisfied, skipping upgrade: netcdf4 in /usr/local/lib/python3.7/dist-packages (from arviz>=0.9.0->pymc3==3.10.0) (1.5.6)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.1->pymc3==3.10.0) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.0->pymc3==3.10.0) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.18.0->pymc3==3.10.0) (2018.9)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->arviz>=0.9.0->pymc3==3.10.0) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz>=0.9.0->pymc3==3.10.0) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.0->arviz>=0.9.0->pymc3==3.10.0) (0.10.0)
# Requirement already satisfied, skipping upgrade: cftime in /usr/local/lib/python3.7/dist-packages (from netcdf4->arviz>=0.9.0->pymc3==3.10.0) (1.4.1)
# Building wheels for collected packages: pymc3
#   Building wheel for pymc3 (PEP 517) ... done
#   Created wheel for pymc3: filename=pymc3-3.10.0-cp37-none-any.whl size=1896907 sha256=8d2103782199667f8e2c95ca95be6dcc4415a4f75521a4c93d34386ead116828
#   Stored in directory: /tmp/pip-ephem-wheel-cache-91qq82b3/wheels/ce/ab/fe/6656d5d28bec60560c94a6975c1670a38e8b194363548a4d05
# Successfully built pymc3
# Installing collected packages: pymc3
#   Found existing installation: pymc3 3.10.0
#     Uninstalling pymc3-3.10.0:
#       Successfully uninstalled pymc3-3.10.0
# Successfully installed pymc3-3.10.0

# %%
# %config InlineBackend.figure_format = 'retina'
RANDOM_SEED = 8927
np.random.seed(RANDOM_SEED)
az.style.use("arviz-darkgrid")
az.rcParams["stats.hdi_prob"] = 0.89  # sets default credible interval used by arviz

# %% [markdown]
# # Q2 Models

# %%
congressData = pd.read_csv("/congress.csv", header=0)
congressData
# Out:
#      inc86  inc88  inc90       v86  ...   v90_adj   recog86   recog88   recog90
# 0        1      1      1  0.745036  ...  0.714029  0.453786  2.095207 -0.253805
# 1        1      1      1  0.673845  ...  0.597050  0.602701  0.455774  1.527571
# 2        1      1      0  0.696457  ...  0.521043  0.504943  0.656609  0.191874
# 3       -1     -1     -1  0.464590  ...  0.234377 -0.502163 -1.829661 -1.819449
# 4       -1     -1      0  0.391095  ...  0.477439  0.633357 -0.947548  0.720765
# ..     ...    ...    ...       ...  ...       ...       ...       ...       ...
# 430      1      0      1  0.726371  ...  0.750401 -0.715950  0.680629 -0.178116
# 431     -1     -1     -1  0.347979  ...  0.437871 -1.353221 -1.439196  0.143544
# 432     -1     -1     -1  0.421110  ...  0.480790 -1.266811 -0.971340 -0.588231
# 433      0     -1      0  0.387486  ...  0.607843 -0.594891 -0.881916  0.076238
# 434      1      1      0  0.777822  ...  0.683847  0.601228  0.691868  1.675772
#
# [435 rows x 12 columns]

# %% [markdown]
# **2.1 Models**

# %%
with pm.Model() as incumbent :
    sigma = pm.Exponential("sigma", 1)
    alpha = pm.Normal('alpha', mu=0, sigma=0.2)
    beta86 = pm.Normal('beta86', mu=np.mean(congressData['v86_adj']), sigma=np.std(congressData['v86_adj']))
    betaInc88 = pm.Normal('betaInc88', mu=np.mean(congressData['inc88']), sigma=np.std(congressData['inc88']))
    inc_mus = pm.Deterministic('inc_mus', alpha + beta86 * congressData['v86_adj'] + betaInc88*congressData['inc88'])
    inc_votes = pm.Normal('inc_votes', mu=inc_mus, sigma=sigma, observed=congressData['v88_adj'])

    post_vote = pm.sample(1000, tune=1000)
    pred_vote = pm.sample_posterior_predictive(post_vote)
    incumbent_trace = pm.sample(return_inferencedata=True)

with pm.Model() as incumbent_no86 :
    sigma = pm.Exponential("sigma", 1)
    alpha = pm.Normal('alpha', mu=0, sigma=0.2)
    betaInc88 = pm.Normal('betaInc88', mu=np.mean(congressData['inc88']), sigma=np.std(congressData['inc88']))
    inc_no86_mus = pm.Deterministic('inc_no86_mus', alpha + betaInc88*congressData['inc88'])
    inc_no86_votes = pm.Normal('inc_no86_votes', mu=inc_no86_mus, sigma=sigma, observed=congressData['v88_adj'])

    post_no86 = pm.sample(1000, tune=1000)
    pred_no86 = pm.sample_posterior_predictive(post_no86)
    incumbent_no86_trace = pm.sample(return_inferencedata=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaInc88, beta86, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:05<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 6 seconds.
# The number of effective samples is smaller than 25% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaInc88, beta86, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 6 seconds.
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaInc88, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:03<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 3 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaInc88, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:02<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 3 seconds.

# %%
az.summary(post_vote, '~inc_mus')
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3.py:92: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#             mean     sd  hdi_5.5%  hdi_94.5%  ...  ess_sd  ess_bulk  ess_tail  r_hat
# alpha      0.236  0.016     0.208      0.260  ...   506.0     506.0     662.0   1.01
# beta86     0.525  0.031     0.477      0.578  ...   500.0     500.0     621.0   1.01
# betaInc88  0.096  0.007     0.086      0.107  ...   545.0     545.0     751.0   1.00
# sigma      0.067  0.002     0.064      0.071  ...  1002.0    1001.0    1053.0   1.00
#
# [4 rows x 11 columns]

# %%
az.waic(incumbent_trace, incumbent)
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:1468: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   "For one or more samples the posterior variance of the log predictive "
# Computed from 2000 by 435 log-likelihood matrix
#
#           Estimate       SE
# elpd_waic   553.93    19.74
# p_waic        6.01        -
#
# There has been a warning during the calculation. Please check the results.

# %%
az.summary(post_no86, '~inc_no86_mus')
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3.py:92: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#             mean     sd  hdi_5.5%  hdi_94.5%  ...  ess_sd  ess_bulk  ess_tail  r_hat
# alpha      0.506  0.004     0.499      0.512  ...  2585.0    2558.0    1415.0    1.0
# betaInc88  0.191  0.004     0.184      0.197  ...  2799.0    2818.0    1158.0    1.0
# sigma      0.085  0.003     0.080      0.089  ...  2051.0    2125.0    1466.0    1.0
#
# [3 rows x 11 columns]

# %%
az.waic(incumbent_no86_trace, incumbent_no86)
# Out:
# Computed from 2000 by 435 log-likelihood matrix
#
#           Estimate       SE
# elpd_waic   452.99    18.27
# p_waic        3.38        -

# %% [markdown]
# **2.2 Model**

# %%
with pm.Model() as incumbent_90 :
    sigma = pm.Exponential("sigma", 1)
    alpha = pm.Normal('alpha', mu=0, sigma=0.2)
    beta88 = pm.Normal('beta88', mu=0.5, sigma=0.2)
    betaInc90 = pm.Normal('betaInc90', mu=np.mean(congressData['inc90']), sigma=np.std(congressData['inc90']))
    inc_90_mus = pm.Deterministic('inc_90_mus', alpha + beta88*inc_votes + betaInc90*congressData['inc90'])
    votes_90 = pm.Normal('votes_90', mu=inc_90_mus, sigma=sigma, observed=congressData['v90_adj'])

    post_90 = pm.sample(1000, tune=1000)
    pred_90 = pm.sample_posterior_predictive(post_90)
    incumbent_90_trace = pm.sample(return_inferencedata=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaInc90, beta88, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 6 seconds.
# The number of effective samples is smaller than 25% for some parameters.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:06<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaInc90, beta88, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:06<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 6 seconds.
# The acceptance probability does not match the target. It is 0.8890663533488369, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
az.summary(post_90, '~inc_90_mus')
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3.py:92: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#             mean     sd  hdi_5.5%  hdi_94.5%  ...  ess_sd  ess_bulk  ess_tail  r_hat
# alpha      0.250  0.020     0.218      0.280  ...   501.0     503.0     657.0    1.0
# beta88     0.519  0.039     0.457      0.580  ...   492.0     491.0     652.0    1.0
# betaInc90  0.064  0.008     0.051      0.077  ...   533.0     552.0     693.0    1.0
# sigma      0.081  0.003     0.077      0.085  ...  1054.0    1056.0    1042.0    1.0
#
# [4 rows x 11 columns]

# %%
az.waic(incumbent_90_trace, incumbent_90)
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:1468: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   "For one or more samples the posterior variance of the log predictive "
# Computed from 2000 by 435 log-likelihood matrix
#
#           Estimate       SE
# elpd_waic   477.15    19.17
# p_waic        5.08        -
#
# There has been a warning during the calculation. Please check the results.

# %%
az.plot_trace(incumbent_90_trace)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# HDI per Seat

# %%
az.hdi(pred_90['votes_90'], hdi_prob=0.89)
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:496: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   FutureWarning,
# array([[ 2.42904646e-02,  1.62205766e+00],
#        [-1.19392286e-02,  1.58819433e+00],
#        [-6.71112081e-02,  1.55186031e+00],
#        [-4.23700684e-01,  1.14857194e+00],
#        [-4.17905408e-01,  1.17100634e+00],
#        [-4.97139857e-01,  1.11093094e+00],
#        [-8.37390974e-02,  1.49841401e+00],
#        [-5.69520934e-01,  1.02944904e+00],
#        [-5.59643180e-01,  1.01738980e+00],
#        [-5.34799575e-02,  1.58332771e+00],
#        [-2.55047549e-02,  1.57666996e+00],
#        [ 3.71896561e-02,  1.64589893e+00],
#        [ 1.73137173e-02,  1.65105797e+00],
#        [ 3.20432295e-02,  1.66478916e+00],
#        [-1.67557173e-02,  1.58613561e+00],
#        [-3.01040971e-02,  1.59073406e+00],
#        [-2.86421051e-02,  1.56479478e+00],
#        [-1.75013915e-02,  1.57350452e+00],
#        [ 5.99565416e-02,  1.69478958e+00],
#        [-3.73523281e-01,  1.20717353e+00],
#        [-4.98155402e-01,  1.08800814e+00],
#        [-1.51166906e-01,  1.45207071e+00],
#        [-4.60928263e-01,  1.10959224e+00],
#        [ 2.36907849e-01,  5.36617651e-01],
#        [ 2.49336356e-02,  1.62935248e+00],
#        [-4.41355145e-02,  1.56964904e+00],
#        [ 1.22100416e-02,  1.60649974e+00],
#        [-3.20620088e-02,  1.56594892e+00],
#        [-4.88510797e-01,  1.09340793e+00],
#        [ 3.34324985e-02,  1.66503963e+00],
#        [-4.80342090e-01,  1.10226784e+00],
#        [-5.39789998e-01,  1.06018562e+00],
#        [-5.60868024e-01,  1.05175622e+00],
#        [ 7.69451990e-03,  1.63351434e+00],
#        [ 8.60743667e-03,  1.61953952e+00],
#        [-8.02363171e-02,  1.52409652e+00],
#        [-4.59266634e-02,  1.57973980e+00],
#        [-3.97004104e-02,  1.56845214e+00],
#        [-3.52627840e-02,  1.57473825e+00],
#        [-8.63487528e-02,  1.53239383e+00],
#        [-5.28126613e-01,  1.04273771e+00],
#        [ 3.61174202e-02,  1.67176378e+00],
#        [-4.90102191e-03,  1.60871047e+00],
#        [ 2.92129549e-03,  1.60173437e+00],
#        [-3.20757661e-03,  1.61025140e+00],
#        [-1.49310067e-01,  1.44805511e+00],
#        [-5.65472313e-01,  1.03070775e+00],
#        [ 3.25568728e-01,  7.01897076e-01],
#        [ 3.27492903e-02,  1.64199043e+00],
#        [-5.02825789e-01,  1.06465057e+00],
#        [-5.09432747e-01,  1.10873565e+00],
#        [-5.08605316e-01,  1.09741641e+00],
#        [-1.05134139e-01,  1.50698995e+00],
#        [-5.31744775e-01,  1.05643348e+00],
#        [ 2.56110827e-01,  5.48578743e-01],
#        [ 4.60840373e-01,  8.38088409e-01],
#        [-4.79283870e-01,  1.11372912e+00],
#        [-5.07568611e-02,  1.57605566e+00],
#        [ 3.09192776e-02,  1.65008737e+00],
#        [-5.01385204e-03,  1.61558025e+00],
#        [-3.24826987e-02,  1.59646536e+00],
#        [ 7.21729007e-03,  1.60327910e+00],
#        [ 8.55616255e-03,  1.62862252e+00],
#        [ 3.62521015e-02,  1.64879138e+00],
#        [-3.29713111e-01,  1.24843370e+00],
#        [ 4.72334264e-02,  1.65675456e+00],
#        [-4.77276219e-01,  1.10486824e+00],
#        [-3.10500590e-02,  1.58307055e+00],
#        [ 5.13496795e-02,  1.65156309e+00],
#        [ 1.27401729e-02,  1.62045057e+00],
#        [-3.89611367e-02,  1.57435600e+00],
#        [-5.19379170e-01,  1.07122025e+00],
#        [-6.79151698e-02,  1.55330230e+00],
#        [-3.28904808e-02,  1.60950787e+00],
#        [-3.36277549e-01,  1.25171332e+00],
#        [ 2.19714409e-02,  1.61213317e+00],
#        [-5.20357753e-01,  1.08501961e+00],
#        [ 3.12431240e-02,  1.63806896e+00],
#        [-4.46630994e-01,  1.13620213e+00],
#        [-2.44011351e-02,  1.56711454e+00],
#        [-8.16210661e-02,  1.52000571e+00],
#        [-2.87221197e-02,  1.60814075e+00],
#        [ 4.56777435e-01,  8.38228269e-01],
#        [ 2.14692903e-01,  5.18444316e-01],
#        [-3.16124605e-02,  1.56862958e+00],
#        [-4.62129500e-02,  1.57247640e+00],
#        [ 4.35880206e-01,  8.06133972e-01],
#        [-1.64153309e-02,  1.59047848e+00],
#        [-8.26207505e-02,  1.50549981e+00],
#        [-4.53604404e-01,  1.14718947e+00],
#        [ 2.25783146e-02,  1.62375402e+00],
#        [-2.18834012e-02,  1.57450119e+00],
#        [-4.91207562e-01,  1.08283825e+00],
#        [-4.73794358e-01,  1.10273784e+00],
#        [-8.08136285e-02,  1.49720427e+00],
#        [-4.89106681e-01,  1.05509942e+00],
#        [-4.54210486e-01,  1.13915412e+00],
#        [-2.97806108e-03,  1.59568940e+00],
#        [-1.18751674e-01,  1.46051801e+00],
#        [-5.28457314e-03,  1.62200910e+00],
#        [ 2.73114445e-02,  1.63432789e+00],
#        [ 3.03064216e-02,  1.65350433e+00],
#        [-5.35850837e-02,  1.54361907e+00],
#        [-4.82746565e-01,  1.11040413e+00],
#        [-1.92796894e-02,  1.59462508e+00],
#        [-3.43269909e-02,  1.57613151e+00],
#        [-4.57965519e-01,  1.13750005e+00],
#        [-5.43666897e-01,  1.04214037e+00],
#        [-5.38975170e-01,  1.03032046e+00],
#        [-1.90902061e-02,  1.58251609e+00],
#        [-6.44783726e-02,  1.56545098e+00],
#        [-6.07651247e-02,  1.55556571e+00],
#        [-2.28577235e-03,  1.61482936e+00],
#        [ 3.87524882e-01,  7.06858597e-01],
#        [-3.59607423e-01,  1.22422020e+00],
#        [-4.40060636e-04,  1.62574902e+00],
#        [-3.09090555e-02,  1.59089639e+00],
#        [-2.23755893e-02,  1.60298530e+00],
#        [ 3.85243994e-02,  1.65376184e+00],
#        [-5.72195997e-01,  1.02043238e+00],
#        [ 1.35135350e-02,  1.61886879e+00],
#        [-4.65302542e-01,  1.15203528e+00],
#        [-5.86487241e-01,  1.00480075e+00],
#        [-2.85844645e-02,  1.58937961e+00],
#        [ 4.66224746e-02,  1.65852332e+00],
#        [-1.53359072e-02,  1.58801612e+00],
#        [-5.43513848e-01,  1.05618566e+00],
#        [ 5.25736013e-02,  1.68337995e+00],
#        [ 2.05888992e-02,  1.65445263e+00],
#        [-2.89487059e-03,  1.60078409e+00],
#        [-8.65669832e-02,  1.54453901e+00],
#        [-4.88275130e-01,  1.10571496e+00],
#        [-6.03735694e-01,  9.76097377e-01],
#        [-5.15114790e-01,  1.09020223e+00],
#        [-1.17848427e-03,  1.61430306e+00],
#        [-1.80828749e-03,  1.60600432e+00],
#        [-5.16105114e-01,  1.07030812e+00],
#        [ 2.44268447e-02,  1.63814794e+00],
#        [-3.75791999e-02,  1.55934231e+00],
#        [-6.77405696e-03,  1.61236964e+00],
#        [ 2.78775392e-02,  1.62307848e+00],
#        [ 4.26299396e-02,  1.64617717e+00],
#        [-4.91355155e-01,  1.09197630e+00],
#        [-4.58622875e-01,  1.16423111e+00],
#        [-2.38089344e-02,  1.60050729e+00],
#        [-5.19880653e-02,  1.55720970e+00],
#        [-3.08942214e-02,  1.59013609e+00],
#        [-5.40396884e-01,  1.07064930e+00],
#        [-9.33789981e-03,  1.60371608e+00],
#        [-5.17952439e-01,  1.05897106e+00],
#        [ 2.23412722e-01,  5.32935410e-01],
#        [-3.71217905e-02,  1.58940704e+00],
#        [ 3.11399015e-02,  1.64938753e+00],
#        [-2.08099945e-02,  1.59021904e+00],
#        [ 8.77540419e-04,  1.60222416e+00],
#        [-5.65566125e-01,  1.03280496e+00],
#        [ 4.88653411e-01,  8.67397402e-01],
#        [ 3.42432563e-02,  1.65165279e+00],
#        [-3.13174950e-02,  1.58617329e+00],
#        [ 2.87183752e-02,  1.62720588e+00],
#        [-1.62748470e-02,  1.62779360e+00],
#        [ 2.86064696e-03,  1.62738021e+00],
#        [-4.90413677e-01,  1.09215745e+00],
#        [-1.86777395e-03,  1.58350294e+00],
#        [-5.69707924e-01,  1.01776889e+00],
#        [-5.01546827e-01,  1.07974329e+00],
#        [-4.92204884e-01,  1.12281824e+00],
#        [ 3.31826764e-02,  1.63548539e+00],
#        [-1.26975157e-01,  1.48084185e+00],
#        [-8.31392964e-02,  1.53310718e+00],
#        [-4.52851066e-01,  1.13621230e+00],
#        [-4.85911819e-01,  1.08062866e+00],
#        [-5.53085639e-01,  1.03063422e+00],
#        [-4.01366391e-01,  1.21582020e+00],
#        [-8.17281422e-02,  1.52723228e+00],
#        [-5.85745622e-02,  1.54894313e+00],
#        [-5.43288159e-01,  1.05555828e+00],
#        [-8.84960213e-02,  1.50786174e+00],
#        [-5.09976193e-01,  1.10360422e+00],
#        [ 2.42788886e-01,  5.54867966e-01],
#        [-4.92737236e-01,  1.10198461e+00],
#        [-2.04106901e-03,  1.61002864e+00],
#        [-4.76977996e-01,  1.13935037e+00],
#        [-4.69988357e-02,  1.55669603e+00],
#        [-3.96582354e-01,  1.20431199e+00],
#        [-5.49055042e-01,  1.02297660e+00],
#        [-8.03771781e-03,  1.61755442e+00],
#        [-4.77155195e-01,  1.13037887e+00],
#        [-3.30356329e-02,  1.59282200e+00],
#        [-1.03742340e-01,  1.53603435e+00],
#        [-2.58711645e-02,  1.58138476e+00],
#        [-3.42254402e-03,  1.57197753e+00],
#        [-1.09789316e-01,  1.50442807e+00],
#        [-1.40359458e-02,  1.57267503e+00],
#        [-2.57321244e-02,  1.58661938e+00],
#        [-4.88693959e-03,  1.58473934e+00],
#        [-2.21094450e-02,  1.57856529e+00],
#        [ 2.63581278e-01,  5.84411812e-01],
#        [-5.22438605e-03,  1.60468234e+00],
#        [-4.39383281e-01,  1.18173235e+00],
#        [ 4.73572159e-02,  1.63594736e+00],
#        [-3.48385824e-02,  1.58751533e+00],
#        [-4.33763233e-01,  1.13752635e+00],
#        [-3.66024621e-02,  1.58659272e+00],
#        [-5.70178596e-01,  1.02702711e+00],
#        [-5.01893101e-01,  1.09621348e+00],
#        [ 2.40964275e-01,  5.53304179e-01],
#        [-5.42887764e-01,  1.05014859e+00],
#        [-1.44911012e-02,  1.59184004e+00],
#        [-3.56325934e-03,  1.61601953e+00],
#        [-1.77911649e-02,  1.59562213e+00],
#        [-2.10940845e-02,  1.56638483e+00],
#        [-6.36485268e-02,  1.56072403e+00],
#        [ 2.09400881e-02,  1.63527327e+00],
#        [-1.34305824e-02,  1.61732151e+00],
#        [-3.76219829e-02,  1.56190320e+00],
#        [ 2.74512215e-02,  1.61259998e+00],
#        [ 1.95148598e-02,  1.63760384e+00],
#        [-4.92953256e-01,  1.05565610e+00],
#        [-6.45267429e-02,  1.55965564e+00],
#        [-5.35871389e-01,  1.05297303e+00],
#        [-4.40656168e-02,  1.56725193e+00],
#        [-5.05721097e-01,  1.08050520e+00],
#        [-4.54036306e-01,  1.13805974e+00],
#        [-5.34299332e-01,  1.05191117e+00],
#        [ 2.70039879e-01,  5.86451621e-01],
#        [-5.26425900e-01,  1.04789527e+00],
#        [ 2.33857804e-01,  5.33794632e-01],
#        [-5.55924482e-01,  1.03454684e+00],
#        [-2.03482571e-02,  1.58508771e+00],
#        [-5.04686492e-01,  1.09660601e+00],
#        [-4.78402149e-02,  1.56370767e+00],
#        [-4.83551808e-01,  1.10656501e+00],
#        [ 5.64518941e-02,  1.66557274e+00],
#        [-3.14750199e-02,  1.58059137e+00],
#        [-4.34779016e-01,  1.15904052e+00],
#        [-4.50030456e-01,  1.13145268e+00],
#        [ 1.46292752e-03,  1.60876068e+00],
#        [ 4.63866494e-01,  8.49919314e-01],
#        [-5.37785497e-01,  1.06781248e+00],
#        [-1.66631560e-02,  1.57454457e+00],
#        [-2.80046963e-03,  1.60936100e+00],
#        [ 4.51680414e-01,  8.24511270e-01],
#        [-5.54569417e-01,  1.05346200e+00],
#        [-4.99883803e-01,  1.09515195e+00],
#        [-4.55745152e-01,  1.14574502e+00],
#        [-4.39799694e-02,  1.54236430e+00]])

# %% [markdown]
# True Vote Results

# %%
v90 = np.array(congressData['v90'])
v90Dem = v90[np.where(v90 > 0.5)]
np.shape(v90Dem)
# Out:
# (267,)

# %% [markdown]
# Simulated Results

# %%
estimated_v90 = np.array([np.mean(arr) for arr in np.array(az.hdi(pred_90['votes_90'], hdi_prob=0.89))])
np.shape(np.where(estimated_v90 > 0.5))
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:496: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   FutureWarning,
# (1, 260)

# %% [markdown]
# **2.3**

# %%
with pm.Model() as incumbent_recog :
    sigma = pm.Exponential("sigma", 1)
    alpha = pm.Normal('alpha', mu=0, sigma=0.2)
    beta86 = pm.Normal('beta86', mu=np.mean(congressData['v86_adj']), sigma=np.std(congressData['v86_adj']))
    betaInc88 = pm.Normal('betaInc88', mu=np.mean(congressData['inc88']), sigma=np.std(congressData['inc88']))
    betaRecog88 = pm.Normal('betaRecog88', mu=np.mean(congressData['recog88']), sigma=np.std(congressData['recog88']))
    inc_recog_mus = pm.Deterministic('inc_recog_mus', alpha + beta86 * congressData['v86_adj'] + betaInc88*congressData['inc88'] + betaRecog88*congressData['recog88'])
    inc_recog_votes = pm.Normal('inc_recog_votes', mu=inc_recog_mus, sigma=sigma, observed=congressData['v88_adj'])

    post_vote_recog = pm.sample(1000, tune=1000)
    pred_vote_recog = pm.sample_posterior_predictive(post_vote_recog)
    incumbent_recog_trace = pm.sample(return_inferencedata=True)

with pm.Model() as incumbent_recogsq :
    sigma = pm.Exponential("sigma", 1)
    alpha = pm.Normal('alpha', mu=0, sigma=0.2)
    beta86 = pm.Normal('beta86', mu=np.mean(congressData['v86_adj']), sigma=np.std(congressData['v86_adj']))
    betaInc88 = pm.Normal('betaInc88', mu=np.mean(congressData['inc88']), sigma=np.std(congressData['inc88']))
    betaRecog88 = pm.Normal('betaRecog88', mu=np.mean(congressData['recog88']), sigma=np.std(congressData['recog88']))
    betaRecog88sq = pm.Normal('betaRecog88sq', mu=np.mean(congressData['recog88']), sigma=np.std(congressData['recog88']))
    inc_recogsq_mus = pm.Deterministic('inc_recogsq_mus', alpha + beta86 * congressData['v86_adj'] + betaInc88*congressData['inc88'] + betaRecog88*congressData['recog88'] + betaRecog88sq*congressData['recog88']**2)
    inc_recogsq_votes = pm.Normal('inc_recogsq_votes', mu=inc_recogsq_mus, sigma=sigma, observed=congressData['v88_adj'])

    post_vote_recogsq = pm.sample(1000, tune=1000)
    pred_vote_recogsq = pm.sample_posterior_predictive(post_vote_recogsq)
    incumbent_recogsq_trace = pm.sample(return_inferencedata=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaRecog88, betaInc88, beta86, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:07<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 7 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:02<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaRecog88, betaInc88, beta86, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:07<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 7 seconds.
# The acceptance probability does not match the target. It is 0.7216308307148386, but should be close to 0.8. Try to increase the number of tuning steps.
# /usr/local/lib/python3.7/dist-packages/pymc3/sampling.py:468: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   FutureWarning,
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaRecog88sq, betaRecog88, betaInc88, beta86, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:08<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 9 seconds.
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 00:03<00:00]
#     </div>
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [betaRecog88sq, betaRecog88, betaInc88, beta86, alpha, sigma]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4000' class='' max='4000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [4000/4000 00:08<00:00 Sampling 2 chains, 0 divergences]
#     </div>
# Sampling 2 chains for 1_000 tune and 1_000 draw iterations (2_000 + 2_000 draws total) took 9 seconds.

# %%
az.summary(post_vote_recog, '~inc_recog_mus')
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3.py:92: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#               mean     sd  hdi_5.5%  ...  ess_bulk  ess_tail  r_hat
# alpha        0.259  0.017     0.233  ...     715.0     960.0    1.0
# beta86       0.488  0.032     0.436  ...     708.0    1001.0    1.0
# betaInc88    0.083  0.007     0.072  ...     775.0     979.0    1.0
# betaRecog88  0.026  0.005     0.019  ...     881.0     839.0    1.0
# sigma        0.065  0.002     0.061  ...    1113.0     850.0    1.0
#
# [5 rows x 11 columns]

# %%
az.waic(incumbent_recog_trace, inc_recog_votes)
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:1468: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   "For one or more samples the posterior variance of the log predictive "
# Computed from 2000 by 435 log-likelihood matrix
#
#           Estimate       SE
# elpd_waic   569.10    18.12
# p_waic        6.81        -
#
# There has been a warning during the calculation. Please check the results.

# %%
az.summary(post_vote_recogsq, '~inc_recogsq_mus')
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/data/io_pymc3.py:92: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   FutureWarning,
#                 mean     sd  hdi_5.5%  ...  ess_bulk  ess_tail  r_hat
# alpha          0.263  0.016     0.237  ...     925.0    1053.0    1.0
# beta86         0.487  0.030     0.442  ...     897.0     922.0    1.0
# betaInc88      0.082  0.007     0.072  ...    1062.0    1370.0    1.0
# betaRecog88    0.025  0.005     0.018  ...    1590.0    1400.0    1.0
# betaRecog88sq -0.003  0.003    -0.008  ...    1848.0    1267.0    1.0
# sigma          0.065  0.002     0.062  ...    1344.0    1191.0    1.0
#
# [6 rows x 11 columns]

# %%
az.waic(incumbent_recogsq_trace, inc_recogsq_votes)
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:1468: UserWarning: For one or more samples the posterior variance of the log predictive densities exceeds 0.4. This could be indication of WAIC starting to fail.
# See http://arxiv.org/abs/1507.04544 for details
#   "For one or more samples the posterior variance of the log predictive "
# Computed from 2000 by 435 log-likelihood matrix
#
#           Estimate       SE
# elpd_waic   569.54    18.11
# p_waic        7.16        -
#
# There has been a warning during the calculation. Please check the results.

# %%
compare_df = az.compare(
    {
        "incumbent+vote": incumbent_trace,
        "incumbent+vote+recog": incumbent_recog_trace,
        "incumbent+vote+recog+recogsq": incumbent_recogsq_trace,
    }
)
compare_df
# Out:
# /usr/local/lib/python3.7/dist-packages/arviz/stats/stats.py:147: UserWarning: The default method used to estimate the weights for each model,has changed from BB-pseudo-BMA to stacking
#   "The default method used to estimate the weights for each model,"
#                               rank         loo  ...  warning  loo_scale
# incumbent+vote+recog+recogsq     0  569.557546  ...    False        log
# incumbent+vote+recog             1  569.043487  ...    False        log
# incumbent+vote                   2  553.921097  ...    False        log
#
# [3 rows x 9 columns]
